# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data
df1= pd.read_csv('Youth_Risk_Behavioral_Surveillance_System__YRBSS__Data.csv')
df2= pd.read_csv('Youth_Tobacco_Survey__YTS__Data (1).csv')

# %%
df1.head() # check the first 5 lines of data
# Out:
#    YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0  1999           MA  Massachusetts  Tobacco Use - Survey Data
# 1  2005           OH           Ohio  Tobacco Use - Survey Data
# 2  1997           IA           Iowa  Tobacco Use - Survey Data
# 3  2007           LA      Louisiana  Tobacco Use - Survey Data
# 4  2015           ID          Idaho  Tobacco Use - Survey Data
#
#                        TopicDesc     MeasureDesc  \
# 0          Cigarette Use (Youth)  Smoking Status
# 1          Cigarette Use (Youth)  Smoking Status
# 2  Smokeless Tobacco Use (Youth)     User Status
# 3              Cigar Use (Youth)  Smoking Status
# 4              Cigar Use (Youth)  Smoking Status
#
#                        SubMeasure DataSource  Response Data_Value_Unit  ...  \
# 0       Frequent Cigarette Smoker      YRBSS  Frequent               %  ...
# 1        Current Cigarette Smoker      YRBSS   Current               %  ...
# ...

# %%
df2.head()
# Out:
#    YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0  2004           OH           Ohio  Tobacco Use – Survey Data
# 1  2008           AL        Alabama  Tobacco Use – Survey Data
# 2  2015           WV  West Virginia  Tobacco Use – Survey Data
# 3  2005           IL       Illinois  Tobacco Use – Survey Data
# 4  2005           CT    Connecticut  Tobacco Use – Survey Data
#
#                        TopicDesc     MeasureDesc DataSource  Response  \
# 0          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 1          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 2  Smokeless Tobacco Use (Youth)     User Status        YTS  Frequent
# 3          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 4  Smokeless Tobacco Use (Youth)     User Status        YTS      Ever
#
#   Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0               %      Percentage  ...  (40.060210141, -82.404260056)
# ...

# %%
df1.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'TopicType', 'TopicDesc',
#        'MeasureDesc', 'SubMeasure', 'DataSource', 'Response',
#        'Data_Value_Unit', 'Data_Value_Type', 'Data_Value',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Data_Value_Std_Err', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Sample_Size', 'Gender', 'Age', 'Race', 'Education', 'GeoLocation',
#        'TopicTypeId', 'TopicId', 'MeasureId', 'StratificationID1',
#        'StratificationID2', 'StratificationID3', 'StratificationID4',
#        'SubMeasureID', 'DisplayOrder'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'TopicType', 'TopicDesc',
#        'MeasureDesc', 'DataSource', 'Response', 'Data_Value_Unit',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Data_Value_Std_Err', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size', 'Gender', 'Race', 'Age',
#        'Education', 'GeoLocation', 'TopicTypeId', 'TopicId', 'MeasureId',
#        'StratificationID1', 'StratificationID2', 'StratificationID3',
#        'StratificationID4', 'SubMeasureID', 'DisplayOrder'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38708 entries, 0 to 38707
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YEAR                        38708 non-null  int64
#  1   LocationAbbr                38708 non-null  object
#  2   LocationDesc                38708 non-null  object
#  3   TopicType                   38708 non-null  object
#  4   TopicDesc                   38708 non-null  object
#  5   MeasureDesc                 38708 non-null  object
#  6   SubMeasure                  38708 non-null  object
#  7   DataSource                  38708 non-null  object
#  8   Response                    38708 non-null  object
#  9   Data_Value_Unit             38708 non-null  object
#  10  Data_Value_Type             38708 non-null  object
#  11  Data_Value                  24275 non-null  float64
#  12  Data_Value_Footnote_Symbol  14433 non-null  object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10600 entries, 0 to 10599
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YEAR                        10600 non-null  int64
#  1   LocationAbbr                10600 non-null  object
#  2   LocationDesc                10600 non-null  object
#  3   TopicType                   10600 non-null  object
#  4   TopicDesc                   10600 non-null  object
#  5   MeasureDesc                 10600 non-null  object
#  6   DataSource                  10600 non-null  object
#  7   Response                    8190 non-null   object
#  8   Data_Value_Unit             10600 non-null  object
#  9   Data_Value_Type             10600 non-null  object
#  10  Data_Value                  10080 non-null  float64
#  11  Data_Value_Footnote_Symbol  517 non-null    object
#  12  Data_Value_Footnote         517 non-null    object
# ...

# %%
List=['LocationAbbr', 'Data_Value_Unit', 'SubMeasure', 'TopicType', 'MeasureDesc', 'DataSource', 'Response', 'TopicTypeId', 'TopicId', 'MeasureId', 'StratificationID1','StratificationID2', 'StratificationID3', 'StratificationID4', 'SubMeasureID']
df1.drop(columns=List, inplace = True)
df1.head()
# Out:
#    YEAR   LocationDesc                      TopicDesc Data_Value_Type  \
# 0  1999  Massachusetts          Cigarette Use (Youth)      Percentage
# 1  2005           Ohio          Cigarette Use (Youth)      Percentage
# 2  1997           Iowa  Smokeless Tobacco Use (Youth)      Percentage
# 3  2007      Louisiana              Cigar Use (Youth)      Percentage
# 4  2015          Idaho              Cigar Use (Youth)      Percentage
#
#    Data_Value Data_Value_Footnote_Symbol  \
# 0        20.9                        NaN
# 1        11.8                        NaN
# 2        22.4                        NaN
# 3         NaN                          *
# 4         NaN                          *
#
#                                  Data_Value_Footnote  Data_Value_Std_Err  \
# 0                                                NaN                 4.4
# 1                                                NaN                 2.9
# ...

# %%
pd.concat([df1['Data_Value_Footnote_Symbol'],
           df1['Data_Value_Footnote'], 
           df1['Gender'], df1['Age'], df1['Education'], df1['TopicDesc']]).unique()
# Out:
# array([nan, '*',
#        'Data in these cells have been suppressed because of a small sample size',
#        'Overall', 'Male', 'Female', 'All Ages', 'High School',
#        'Middle School', 'Cigarette Use (Youth)',
#        'Smokeless Tobacco Use (Youth)', 'Cigar Use (Youth)',
#        'E-Cigarette Use (Youth)', 'Any Tobacco Use (Youth)'], dtype=object)

# %%
df1.drop(columns=['Data_Value_Type', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Age'], inplace=True)
df1.head()
# Out:
#    YEAR   LocationDesc                      TopicDesc  Data_Value  \
# 0  1999  Massachusetts          Cigarette Use (Youth)        20.9
# 1  2005           Ohio          Cigarette Use (Youth)        11.8
# 2  1997           Iowa  Smokeless Tobacco Use (Youth)        22.4
# 3  2007      Louisiana              Cigar Use (Youth)         NaN
# 4  2015          Idaho              Cigar Use (Youth)         NaN
#
#    Data_Value_Std_Err  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                 4.4                  13.3                   31.3
# 1                 2.9                   7.1                   19.1
# 2                 2.2                  18.2                   27.4
# 3                 NaN                   NaN                    NaN
# 4                 NaN                   NaN                    NaN
#
#    Sample_Size   Gender                           Race    Education  \
# 0        116.0  Overall                  Multiple Race  High School
# ...

# %%
df1.rename(columns={'YEAR':'year', 'LocationDesc':'state', 'TopicDesc':'tabacco_type','Data_Value':'percentage_tabacco_user', 'Gender':'gender', 'Race':'race', 'Education':'education'}, inplace=True)
df1.head()
# Out:
#    year          state                   tabacco_type  \
# 0  1999  Massachusetts          Cigarette Use (Youth)
# 1  2005           Ohio          Cigarette Use (Youth)
# 2  1997           Iowa  Smokeless Tobacco Use (Youth)
# 3  2007      Louisiana              Cigar Use (Youth)
# 4  2015          Idaho              Cigar Use (Youth)
#
#    percentage_tabacco_user  Data_Value_Std_Err  Low_Confidence_Limit  \
# 0                     20.9                 4.4                  13.3
# 1                     11.8                 2.9                   7.1
# 2                     22.4                 2.2                  18.2
# 3                      NaN                 NaN                   NaN
# 4                      NaN                 NaN                   NaN
#
#    High_Confidence_Limit  Sample_Size   gender                           race  \
# 0                   31.3        116.0  Overall                  Multiple Race
# ...

# %%
List=['LocationAbbr', 'Data_Value_Unit', 'TopicType', 'MeasureDesc', 'DataSource', 'Response', 'TopicTypeId', 'TopicId', 'MeasureId', 'StratificationID1','StratificationID2', 'StratificationID3', 'StratificationID4', 'SubMeasureID']
df2.drop(columns=List, inplace = True)
df2.head()
# Out:
#    YEAR   LocationDesc                      TopicDesc Data_Value_Type  \
# 0  2004           Ohio          Cigarette Use (Youth)      Percentage
# 1  2008        Alabama          Cigarette Use (Youth)      Percentage
# 2  2015  West Virginia  Smokeless Tobacco Use (Youth)      Percentage
# 3  2005       Illinois          Cigarette Use (Youth)      Percentage
# 4  2005    Connecticut  Smokeless Tobacco Use (Youth)      Percentage
#
#    Data_Value Data_Value_Footnote_Symbol Data_Value_Footnote  \
# 0        32.2                        NaN                 NaN
# 1        47.8                        NaN                 NaN
# 2        12.7                        NaN                 NaN
# 3        28.5                        NaN                 NaN
# 4        20.5                        NaN                 NaN
#
#    Data_Value_Std_Err  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                 3.2                  25.8                   38.5
# ...

# %%
pd.concat([df2['Data_Value_Footnote_Symbol'],
           df2['Data_Value_Footnote'], 
           df2['Gender'], df2['Age'], df2['Education'], df2['TopicDesc']]).unique()
# Out:
# array([nan, '*',
#        'Data in these cells have been suppressed because of a small sample size',
#        'Overall', 'Female', 'Male', 'All Ages', 'Middle School',
#        'High School', 'Cigarette Use (Youth)',
#        'Smokeless Tobacco Use (Youth)', 'Cessation (Youth)'], dtype=object)

# %%
df2.drop(columns=['Data_Value_Type', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Age'], inplace=True)
df2.head()
# Out:
#    YEAR   LocationDesc                      TopicDesc  Data_Value  \
# 0  2004           Ohio          Cigarette Use (Youth)        32.2
# 1  2008        Alabama          Cigarette Use (Youth)        47.8
# 2  2015  West Virginia  Smokeless Tobacco Use (Youth)        12.7
# 3  2005       Illinois          Cigarette Use (Youth)        28.5
# 4  2005    Connecticut  Smokeless Tobacco Use (Youth)        20.5
#
#    Data_Value_Std_Err  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                 3.2                  25.8                   38.5
# 1                 2.9                  42.1                   53.5
# 2                 1.9                   9.0                   16.4
# 3                 2.2                  24.2                   32.8
# 4                 2.3                  16.0                   25.1
#
#    Sample_Size   Gender       Race      Education  \
# 0       1377.0  Overall  All Races  Middle School
# 1        654.0   Female  All Races    High School
# ...

# %%
df2.rename(columns={'YEAR':'year', 'LocationDesc':'state', 'TopicDesc':'tabacco_type','Data_Value':'percentage_tabacco_user', 'Gender':'gender', 'Race':'race', 'Education':'education'}, inplace=True)
df2.head()
# Out:
#    year          state                   tabacco_type  \
# 0  2004           Ohio          Cigarette Use (Youth)
# 1  2008        Alabama          Cigarette Use (Youth)
# 2  2015  West Virginia  Smokeless Tobacco Use (Youth)
# 3  2005       Illinois          Cigarette Use (Youth)
# 4  2005    Connecticut  Smokeless Tobacco Use (Youth)
#
#    percentage_tabacco_user  Data_Value_Std_Err  Low_Confidence_Limit  \
# 0                     32.2                 3.2                  25.8
# 1                     47.8                 2.9                  42.1
# 2                     12.7                 1.9                   9.0
# 3                     28.5                 2.2                  24.2
# 4                     20.5                 2.3                  16.0
#
#    High_Confidence_Limit  Sample_Size   gender       race      education  \
# 0                   38.5       1377.0  Overall  All Races  Middle School
# 1                   53.5        654.0   Female  All Races    High School
# ...

# %%
df1.isnull().sum()
# Out:
# year                           0
# state                          0
# tabacco_type                   0
# percentage_tabacco_user    14433
# Data_Value_Std_Err         14433
# Low_Confidence_Limit       14433
# High_Confidence_Limit      14433
# Sample_Size                14433
# gender                         0
# race                           0
# education                      0
# GeoLocation                    0
# DisplayOrder                   0
# dtype: int64

# %%
cols = ['percentage_tabacco_user','Data_Value_Std_Err', 'Low_Confidence_Limit', 'High_Confidence_Limit', 'Sample_Size']
df1[cols] = df1[cols].fillna(df1[cols].mean())
df1.isnull().sum()
# Out:
# year                       0
# state                      0
# tabacco_type               0
# percentage_tabacco_user    0
# Data_Value_Std_Err         0
# Low_Confidence_Limit       0
# High_Confidence_Limit      0
# Sample_Size                0
# gender                     0
# race                       0
# education                  0
# GeoLocation                0
# DisplayOrder               0
# dtype: int64

# %%
cols = ['percentage_tabacco_user','Data_Value_Std_Err', 'Low_Confidence_Limit', 'High_Confidence_Limit', 'Sample_Size']
df2[cols] = df2[cols].fillna(df2[cols].mean())
df2.isnull().sum()
# Out:
# year                       0
# state                      0
# tabacco_type               0
# percentage_tabacco_user    0
# Data_Value_Std_Err         0
# Low_Confidence_Limit       0
# High_Confidence_Limit      0
# Sample_Size                0
# gender                     0
# race                       0
# education                  0
# GeoLocation                4
# DisplayOrder               0
# dtype: int64

# %%
df2['GeoLocation'].fillna('ffill', inplace=True)
df2.isna().sum()
# Out:
# year                       0
# state                      0
# tabacco_type               0
# percentage_tabacco_user    0
# Data_Value_Std_Err         0
# Low_Confidence_Limit       0
# High_Confidence_Limit      0
# Sample_Size                0
# gender                     0
# race                       0
# education                  0
# GeoLocation                0
# DisplayOrder               0
# dtype: int64

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 38703    False
# 38704    False
# 38705    False
# 38706    False
# 38707    False
# Length: 38708, dtype: bool

# %%
df2.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10595    False
# 10596    False
# 10597    False
# 10598    False
# 10599    False
# Length: 10600, dtype: bool

# %%
df = pd.concat([df1,df2])
df
# Out:
#        year          state                   tabacco_type  \
# 0      1999  Massachusetts          Cigarette Use (Youth)
# 1      2005           Ohio          Cigarette Use (Youth)
# 2      1997           Iowa  Smokeless Tobacco Use (Youth)
# 3      2007      Louisiana              Cigar Use (Youth)
# 4      2015          Idaho              Cigar Use (Youth)
# ...     ...            ...                            ...
# 10595  2002         Kansas  Smokeless Tobacco Use (Youth)
# 10596  2015       Illinois          Cigarette Use (Youth)
# 10597  2010      Wisconsin              Cessation (Youth)
# 10598  2009      Louisiana          Cigarette Use (Youth)
# 10599  2010       Delaware          Cigarette Use (Youth)
#
#        percentage_tabacco_user  Data_Value_Std_Err  Low_Confidence_Limit  \
# 0                    20.900000            4.400000             13.300000
# 1                    11.800000            2.900000              7.100000
# ...

# %%
df.drop_duplicates()
# Out:
#        year          state                   tabacco_type  \
# 0      1999  Massachusetts          Cigarette Use (Youth)
# 1      2005           Ohio          Cigarette Use (Youth)
# 2      1997           Iowa  Smokeless Tobacco Use (Youth)
# 3      2007      Louisiana              Cigar Use (Youth)
# 4      2015          Idaho              Cigar Use (Youth)
# ...     ...            ...                            ...
# 10595  2002         Kansas  Smokeless Tobacco Use (Youth)
# 10596  2015       Illinois          Cigarette Use (Youth)
# 10597  2010      Wisconsin              Cessation (Youth)
# 10598  2009      Louisiana          Cigarette Use (Youth)
# 10599  2010       Delaware          Cigarette Use (Youth)
#
#        percentage_tabacco_user  Data_Value_Std_Err  Low_Confidence_Limit  \
# 0                    20.900000            4.400000             13.300000
# 1                    11.800000            2.900000              7.100000
# ...

# %%
df = df[['year','state', 'tabacco_type', 'percentage_tabacco_user', 'gender', 'race', 'education']]
df.head()
# Out:
#    year          state                   tabacco_type  \
# 0  1999  Massachusetts          Cigarette Use (Youth)
# 1  2005           Ohio          Cigarette Use (Youth)
# 2  1997           Iowa  Smokeless Tobacco Use (Youth)
# 3  2007      Louisiana              Cigar Use (Youth)
# 4  2015          Idaho              Cigar Use (Youth)
#
#    percentage_tabacco_user   gender                           race  \
# 0                20.900000  Overall                  Multiple Race
# 1                11.800000  Overall               African American
# 2                22.400000     Male                      All Races
# 3                13.715967  Overall  American Indian/Alaska Native
# 4                13.715967  Overall               African American
#
#      education
# 0  High School
# 1  High School
# 2  High School
# 3  High School
# 4  High School

# %%
df['gender'].unique()
# Out:
# array(['Overall', 'Male', 'Female'], dtype=object)

# %%
df['tabacco_type'].unique()
# Out:
# array(['Cigarette Use (Youth)', 'Smokeless Tobacco Use (Youth)',
#        'Cigar Use (Youth)', 'E-Cigarette Use (Youth)',
#        'Any Tobacco Use (Youth)', 'Cessation (Youth)'], dtype=object)

# %%
df.nunique()
# Out:
# year                        22
# state                       53
# tabacco_type                 6
# percentage_tabacco_user    827
# gender                       3
# race                         8
# education                    2
# dtype: int64

# %%
df_R = df.apply(lambda row: row[df['race'].isin(['African American',
       'American Indian/Alaska Native', 'Asian', 'White', 'Hispanic',
       'Pacific Islander'])])
df_R
# Out:
#        year      state                   tabacco_type  \
# 1      2005       Ohio          Cigarette Use (Youth)
# 3      2007  Louisiana              Cigar Use (Youth)
# 4      2015      Idaho              Cigar Use (Youth)
# 5      2009   Maryland              Cigar Use (Youth)
# 6      2011     Hawaii  Smokeless Tobacco Use (Youth)
# ...     ...        ...                            ...
# 38697  2001    Vermont              Cigar Use (Youth)
# 38701  2007   Michigan          Cigarette Use (Youth)
# 38704  2015   Kentucky  Smokeless Tobacco Use (Youth)
# 38705  1995   Missouri  Smokeless Tobacco Use (Youth)
# 38706  1993       Utah          Cigarette Use (Youth)
#
#        percentage_tabacco_user   gender                           race  \
# 1                    11.800000  Overall               African American
# 3                    13.715967  Overall  American Indian/Alaska Native
# 4                    13.715967  Overall               African American
# ...

# %%
df.describe()
# Out:
#                year  percentage_tabacco_user
# count  49308.000000             49308.000000
# mean    2008.450535                15.139284
# std        6.376783                15.184943
# min     1993.000000                 0.000000
# 25%     2003.000000                 4.400000
# 50%     2009.000000                13.715967
# 75%     2015.000000                14.800000
# max     2017.000000                98.000000

# %%
df.groupby('race')['percentage_tabacco_user'].mean()
# Out:
# race
# African American                 12.223337
# All Races                        17.083117
# American Indian/Alaska Native    14.795132
# Asian                            12.247894
# Hispanic                         14.088569
# Multiple Race                    12.947306
# Pacific Islander                 13.907213
# White                            14.379788
# Name: percentage_tabacco_user, dtype: float64

# %%
df.groupby('gender')['percentage_tabacco_user'].mean()
# Out:
# gender
# Female     15.137637
# Male       18.398571
# Overall    14.422214
# Name: percentage_tabacco_user, dtype: float64

# %%
df.groupby('year')['percentage_tabacco_user'].mean()
# Out:
# year
# 1993    25.524941
# 1995    19.646820
# 1997    20.034120
# 1999    19.177205
# 2000    26.600008
# 2001    16.790436
# 2002    25.102460
# 2003    15.684968
# 2004    20.686095
# 2005    15.985440
# 2006    21.716073
# 2007    14.477796
# 2008    18.327556
# 2009    13.795140
# 2010    17.906509
# 2011    12.933170
# 2012    15.942102
# 2013    11.766884
# 2014    16.137768
# 2015    13.451794
# 2016    13.705619
# 2017    11.310286
# Name: percentage_tabacco_user, dtype: float64

# %%
df.groupby('tabacco_type')['percentage_tabacco_user'].mean()
# Out:
# tabacco_type
# Any Tobacco Use (Youth)          20.253945
# Cessation (Youth)                46.491215
# Cigar Use (Youth)                 9.117403
# Cigarette Use (Youth)            18.413785
# E-Cigarette Use (Youth)          16.379303
# Smokeless Tobacco Use (Youth)     8.009171
# Name: percentage_tabacco_user, dtype: float64

# %%
sns.relplot(x='year', y='percentage_tabacco_user', data=df_R, kind='line', marker=True, hue='race', dashes=False)
plt.show()

# %%
df_G = df.apply(lambda row: row[df['gender'].isin(['Female', 'Male'])])
df_G.head()
# Out:
#     year          state                   tabacco_type  \
# 2   1997           Iowa  Smokeless Tobacco Use (Youth)
# 7   2007  New Hampshire          Cigarette Use (Youth)
# 25  2017  New Hampshire        E-Cigarette Use (Youth)
# 28  2013          Maine              Cigar Use (Youth)
# 29  2009       Oklahoma              Cigar Use (Youth)
#
#     percentage_tabacco_user  gender       race      education
# 2                 22.400000    Male  All Races    High School
# 7                 13.715967    Male  All Races    High School
# 25                37.800000  Female  All Races    High School
# 28                 0.700000    Male  All Races  Middle School
# 29                 3.000000    Male  All Races    High School

# %%
sns.catplot(x='tabacco_type', y='percentage_tabacco_user', data=df_G, kind='bar', hue='gender')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='tabacco_type', y='percentage_tabacco_user', data=df_G, kind='bar', hue='education')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='race', y='percentage_tabacco_user', data=df, kind='point', hue='gender', join=False)
plt.xticks(rotation=90)
plt.show()

# %%
df_L = df.groupby('state')['percentage_tabacco_user'].mean()
df_L
# Out:
# state
# Alabama                     18.435425
# Alaska                      14.669550
# Arizona                     15.982501
# Arkansas                    18.774147
# California                  15.635979
# Colorado                    12.860250
# Connecticut                 15.060320
# Delaware                    13.050168
# District of Columbia         9.562460
# Florida                     13.113542
# Georgia                     14.361187
# Guam                        16.503200
# Hawaii                      12.911423
# Idaho                       14.297692
# Illinois                    15.688900
# Indiana                     16.597966
# Iowa                        16.561057
# Kansas                      14.447454
# Kentucky                    16.744157
# Louisiana                   17.808044
# Maine                       10.919453
# Maryland                    10.712370
# Massachusetts               15.046738
# Michigan                    16.015075
# ...

# %%
df.head()
# Out:
#    year          state                   tabacco_type  \
# 0  1999  Massachusetts          Cigarette Use (Youth)
# 1  2005           Ohio          Cigarette Use (Youth)
# 2  1997           Iowa  Smokeless Tobacco Use (Youth)
# 3  2007      Louisiana              Cigar Use (Youth)
# 4  2015          Idaho              Cigar Use (Youth)
#
#    percentage_tabacco_user   gender                           race  \
# 0                20.900000  Overall                  Multiple Race
# 1                11.800000  Overall               African American
# 2                22.400000     Male                      All Races
# 3                13.715967  Overall  American Indian/Alaska Native
# 4                13.715967  Overall               African American
#
#      education
# 0  High School
# 1  High School
# 2  High School
# 3  High School
# 4  High School

# %%
sns.heatmap(df.corr())
# Out:
# /var/folders/6t/3zt4r0xs2gg6kfkqfhtvlm780000gn/T/ipykernel_17309/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >
